# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('GWSI_WW_LEVELS.csv', index_col=0,)
df['WLWA_MEASUREMENT_DATE'] = pd.to_datetime(df['WLWA_MEASUREMENT_DATE'])
site_list = df.index.unique()
print(site_list)
no_sites = len(site_list)
print(no_sites)
df
# Out:
# Index([330725113260201, 314045111565001, 331922112433901, 331907112440701,
#        331914112444201, 331745112474501, 331648112474701, 334118113463501,
#        334729113334201, 332148113073401,
#        ...
#        362436109522602, 362436109522603, 363258109402301, 364251112130001,
#        365412112452401, 365430109400901, 365541112561601, 365610112541201,
#        334514112350301, 343237112084301],
#       dtype='int64', name='WLWA_SITE_WELL_SITE_ID', length=37364)
# 37364
#                         WLWA_ID WLWA_MEASUREMENT_DATE  WLWA_DEPTH_TO_WATER  \
# WLWA_SITE_WELL_SITE_ID
# 330725113260201         2221785            2025-07-02               420.97
# 314045111565001         2221735            2025-07-01                44.50
# 331922112433901         2221758            2025-07-01                44.00
# 331907112440701         2221759            2025-07-01               151.00
# 331914112444201         2221760            2025-07-01               112.00
# ...

# %%
for site in site_list:
   sub = df.loc[site]
   sub.index = sub['WLWA_MEASUREMENT_DATE']
   sub['WLWA_DEPTH_TO_WATER'].plot()

plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 for site in site_list:
#       2    sub = df.loc[site]
# ----> 3    sub.index = sub['WLWA_MEASUREMENT_DATE']
#       4    sub['WLWA_DEPTH_TO_WATER'].plot()
#       6 plt.legend()
#
# File /workspaces/homework_marlanahinkley/.venv/lib/python3.11/site-packages/pandas/core/generic.py:6332, in NDFrame.__setattr__(self, name, value)
#    6330 try:
#    6331     object.__getattribute__(self, name)
# -> 6332     return object.__setattr__(self, name, value)
#    6333 except AttributeError:
#    6334     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /workspaces/homework_marlanahinkley/.venv/lib/python3.11/site-packages/pandas/core/generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     807 @final
# ...
